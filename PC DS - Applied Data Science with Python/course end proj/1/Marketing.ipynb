# %%
# Market based Analysis

# Load the data 
# use pandas pd.read_csv

# check dt_customer
df['dt_Customer'] = pd.to_datetime(df['dt_Customer'])
# check income
df['Income'] = pd.to_numeric(df['Income'])

# missing values in Income -> isna().sum() -> replace with mean income

# Education and Marital Status
# check for missing values
# replace -> ffill, bfill

# create 3 new cols
df['Total_Children'] = df['kidhome'] + df['Teenhome']
df['Age'] = 2025 - df['Year_of_birth']
df['Total_Spends'] = df['MntWines'] + ..................
df['Total_Purchases'] = df['NumCatalogPurchase'] + ....Num cols

# box plot
for col in ['Income','Age','Total_spends','Total_purchases']:
    plt.subplot...
    sns.boxplot....
    plt.subplot....
    sns.histplot

# identify outliers. Implement outlier treatment as needed.
Q1, Q3 = 
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR
df['Income'] -> less than lower and grater than upper. replace that lower or upper value

# Apply one hot encoding on Education, Marital Status, Country
pd.get_dummies(df, columns=['Marital_Status','Country']

sns.heatmap(df.corr(numeric_only=True)

# a.	Older individuals may not possess the same 
# level of technological proficiency and may, therefore, lean toward traditional in-store shopping preferences
            cols -> Age , NumStorePurchases
# b. 
cols -> Total_Children, NumWebPurchases

# c. 
cols -> NumStorePurchases, NumWebPurchases

# d.
create one more col ->
put 1 if country == US
put 0 otherwise
get US data -> df['Cuntry_Us']==1]['Total_spends'].sum()
rest ->df['Cuntry_Us']==0]['Total_spends'].sum() 

# Age vs Acceptance Visual
boxplot(x='AcceptedCmpLast', y='Age', data=df)

# CHildren vs Expenditure
sns.boxplot(x='Total_children', y='Total_spend', data = df)

# Complaint vs
