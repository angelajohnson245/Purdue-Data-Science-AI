# %%
Initial data inspection and data cleaning: 
a. Examine the data initially to identify duplicates, missing values, irrelevant 
entries, or outliers. Check for any instances of erroneous entries and 
rectify them as needed 

load data

df.shape
df.info

identify duplicates
df['id'],duplicated().sum()
handle them -> drop_duplicates
df.drop_duplicates(subset='id', keep='first')

missing values -  df.isna().sum() -> categorical replace with mode value , ffill, bfill
                                  -> numeric -> mean, median

irrelevant entries - date -> convert it to date type

outliers -> IQR - numeric features 
         -> handle outliers

# %%
Refine the data for further processing based on your findings 

release date -> get -> release year

duration -> in ms -> convert it to minutes

# %%
Perform exploratory data analysis and feature engineering 

a. Utilize suitable visualizations to identify the two albums that should be 
recommended to anyone based on the number of popular songs in each 
album 

make use of popularity factor
threshold -> 70 

df -> fetch rows where popularity >=70 -> popular songs
get album nams and popular song count

.head(2) -> top 2 albums

# %%
b. Conduct exploratory data analysis to delve into various features of songs, 
aiming to identify patterns 

plt -> some figures

histogram -> danceability 

scatter plot -> pairwise

# %%
c. Examine the relationship between a song's popularity and various factors, 
exploring how this correlation has evolved 

correlation - heatmap - popularity and other features

# %%
d. Provide insights on the significance of dimensionality reduction 
techniques. Share your ideas and elucidate your observations

PCA ->

pca = PCA(n_components=0.95) keeping 95% variance
X -> dataset
X_pca -> fit_transform(fit the dataset X)

another pca and reduce it to 2 components 
-> plot this

# %%
 Perform cluster analysis 
a. Identify the right number of clusters 
Elbow Method or Silhoutte Score - plot also 
choose any one - to identify number of clusters

b. Use appropriate clustering algorithms 
KMeans - preferred 
Agglomerative , DBSCAN

c. Define each cluster based on the features
labels - clusters are created
summary of the clusters 

Cluster - high energy - high danceability, high tempo 

create cluters along wirg centriods
