# %% [markdown]
# Build DNN using TensorFlow
# -> process of designing and cosntructing NN models using TensorFlow framework.
# -> Define the architecture of the NN, select appropriate layers, activation function, optimization alogorthm
#    and train the model using data
#
# Steps :
# Import libraries
# Load and inspect the data
# Build model
# Train the model

# %%
import tensorflow as tf
from tensorflow import keras # keras is high level API used to build and train neural networks
from tensorflow.keras.layers import MaxPooling2D, Dropout, Flatten, Dense
# MaxPooling2D -> reduce the size of feature to make models fast and aviod overfitting
# Dropout -> randomly turn off some neurons during training to prevent overfitting
# Flatten -> Convert 2D feature maps to 1D Vector befor passing to connected layers
# Dense -> A fully connected neural network layer
import numpy as np
import pandas as pd

# %%
# Load and inspect the dataset
# keras -> datasets -> boston housing dataset
# plit into train and test sets

(train_features, train_labels), (test_features, test_labels) = keras.datasets.boston_housing.load_data()
# Out:
# ...
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 2us/step

# %%
# train features -> mean, std and standarize the train features
train_mean = np.mean(train_features, axis=0)
train_std = np.std(train_features, axis=0)
train_features = (train_features - train_mean) / train_std
print(train_features)
# Out:
# [[-0.27224633 -0.48361547 -0.43576161 ...  1.14850044  0.44807713
#    0.8252202 ]
#  [-0.40342651  2.99178419 -1.33391162 ... -1.71818909  0.43190599
#   -1.32920239]
#  [ 0.1249402  -0.48361547  1.0283258  ...  0.78447637  0.22061726
#   -1.30850006]
#  ...
#  [-0.40202987  0.99079651 -0.7415148  ... -0.71712291  0.07943894
#   -0.67776904]
#  [-0.17292018 -0.48361547  1.24588095 ... -1.71818909 -0.98764362
#    0.42083466]
#  [-0.40422614  2.04394792 -1.20161456 ... -1.30866202  0.23317118
#   -1.15392266]]

# %%
# build the model
# def -> configure the layers -> keras.Sequential
# -> loss function, metric to monitor, optimizer - Adam 
def build_model():
    model = keras.Sequential([
           Dense(20, activation=tf.nn.relu, input_shape=[len(train_features[0])]),
           Dense(1)
    ])
    # creating dense input layer -> 20 neurons, dense - output layer -> 1 neuron
    model.compile(
         optimizer = tf.optimizers.Adam(),
         loss = 'mae',
         metrics = ['mean_absolute_error']
    )
    return model

model = build_model()
print(model.summary)
# Out:
# <bound method Model.summary of <Sequential name=sequential_2, built=True>>
