# %% [markdown]
# # TF Model to TF Lite Model
# ## Lite Model
# * optimized model

# %%
import numpy as np
import sys

print("NumPy version:", np.__version__)
print("Python:", sys.executable)
# Out:
# NumPy version: 1.26.4
# Python: /Users/angelajohnson/miniforge3/envs/tfarm/bin/python

# %%
import numpy as np
import tensorflow as tf

print("NumPy:", np.__version__)
print("TF:", tf.__version__)
# Out:
# NumPy: 1.26.4
# TF: 2.16.2

# %%
# Create model
import tensorflow as tf
import numpy as np


model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[1]),
    tf.keras.layers.Dense(units=16, activation='relu'),
    tf.keras.layers.Dense(units=1)
])

model.compile(
    optimizer='sgd',
    loss='mean_squared_error'
)

# Convert lists to numpy arrays
x = np.array([-1, 0, 1], dtype=np.float32)
y = np.array([-3, -1, 1], dtype=np.float32)

model.fit(x, y, epochs=5)

# Save model
tf.saved_model.save(model, 'saved_model_keras_dir')
# Out:
# Epoch 1/5
# /Users/angelajohnson/miniforge3/envs/tfarm/lib/python3.10/site-packages/keras/src/layers/core/dense.py:95: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-12-21 09:34:36.872950: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M3
# 2025-12-21 09:34:36.873102: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2025-12-21 09:34:36.873105: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2025-12-21 09:34:36.873442: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-12-21 09:34:36.873452: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 1.3759
# Epoch 2/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.2514
# Epoch 3/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1170
# Epoch 4/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9927
# 2025-12-21 09:34:37.183410: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9927
# Epoch 5/5
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.8784
# INFO:tensorflow:Assets written to: saved_model_keras_dir/assets
# INFO:tensorflow:Assets written to: saved_model_keras_dir/assets

# %%
# conver it to lite version
