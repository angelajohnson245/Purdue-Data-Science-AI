# %% [markdown]
# # TensorBoard
#
# * tool that provides the measurements and visualizations requried throughout the machine learning workflow
# * track expriment metrics - loss and accuracy, faciclitate the cisualization of modedl graph
# * enables the projections of embeddings into a lower dimensional space

# %%
# load the tesnorboard extension for jupyter notebook

# %%
# %load_ext tensorboard

# %%
# imports
import tensorflow as tf 
import datetime, os

import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten

# %%
# fashion - mnist 

fashion_mnist = tf.keras.datasets.fashion_mnist

# Load MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize pixel values (0–255 → 0–1)
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# create the model with dense layers 

# sequential through model
# create the model with dense layers
def create_model():
    return tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=(28,28)),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(10, activation='softmax')
    ])

# %%
# training of model 

def train_model():
    model = create_model()
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
    tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
    model.fit(x=x_train, y=y_train, epochs=10, validation_data=(x_test, y_test),
              callbacks=[tensorboard_callback])
    test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
    print("Test Accuracy: ",test_acc)
    print("Test Loss: ", test_loss)
    
train_model()
# Out:
# Epoch 1/10
# 2025-12-20 09:04:07.550506: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 9ms/step - accuracy: 0.8820 - loss: 0.4190 - val_accuracy: 0.9145 - val_loss: 0.3252
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 16s 9ms/step - accuracy: 0.8854 - loss: 0.4640 - val_accuracy: 0.8952 - val_loss: 0.4353
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.8771 - loss: 0.5414 - val_accuracy: 0.9040 - val_loss: 0.4212
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 15s 8ms/step - accuracy: 0.8738 - loss: 0.6043 - val_accuracy: 0.8962 - val_loss: 0.4981
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.8696 - loss: 0.6696 - val_accuracy: 0.9064 - val_loss: 0.4934
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - accuracy: 0.8680 - loss: 0.7303 - val_accuracy: 0.8816 - val_loss: 0.6468
# Epoch 7/10
# ...

# %% [markdown]
# Launch the tensorboard with parameters
# * host 0.0.0.0 -> specifies the host address to which Tensorboard is bound. Bind to all n/w addresses
# * port 6006 -> specifies the port number on which TensorBoard is accessible
# * logdir logs -> specifies the dir containing the log files generated by Tensorflow
#             * will be used as the data source for TensorBoard

# %%
# !tensorboard --host 0.0.0.0 --port 6006 --logdir logs
# Out:
# /Users/angelajohnson/miniforge3/envs/tfarm/lib/python3.10/site-packages/tensorboard/default.py:30: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# TensorBoard 2.16.2 at http://0.0.0.0:6006/ (Press CTRL+C to quit)
# ^C
